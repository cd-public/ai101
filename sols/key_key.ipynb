# %% [markdown]
# <a href="https://colab.research.google.com/github/cd-public/ai101/blob/main/sols/key_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Answer key
#
# Check out the instructions [here](https://cd-public.github.io/ai101/21_key.html).

# %%
from google.colab import ai

# %%
tree_letter = "c"

instructions = "Hello Gemini, I am Colab, not a person, please only reply yes or no as a single word. Don't use sentences or markdown or punctuation or anything like that. I am providing the URLs of two images, answer the question about the images. "
leaf_url = "https://cd-public.github.io/ai101/images/oaks/" + tree_letter + "_leaf.jpg "
tree_url = "https://cd-public.github.io/ai101/images/oaks/" + tree_letter + "_tree.jpg "

# %%
question1 = "Are the leaves smooth with no teeth or lobes?"
question2 = "Are the leaves evergreen?"
question3 = "Is the plant a large tree (rather than being a small shrub)?"
question4 = "Are the leaves narrow, that is, about 4-6 times as long as they are broad, rather than being broad which about 2-3 times as long as broad?"
question5 = "Are the lobes of the leaves bristle-tipped rather than rounded or blunt-pointed with no bristles?"
question6 = "Do the leaves mostly have 3 rather than 7-9 lobes?"
question7 = "Do the leaves have 5-9 deep lobes of 21-27 shallow lobes?"

# %%
ai.generate_text(instructions + leaf_url + tree_url + question1)
# Out:
# 'No'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question2)
# Out:
# 'Yes'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question3)
# Out:
# 'Yes'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question4)
# Out:
# 'Yes'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question5)
# Out:
# 'yes'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question6)
# Out:
# 'No'

# %%
ai.generate_text(instructions + leaf_url + tree_url + question7)
# Out:
# 'Yes'
